# %%
import pandas as pd
import sys
sys.path.append('../')
from repo_utils import checkout_master_fetch_and_reset

apps = pd.read_csv(f"../datasets/applications.csv")

for index, app in apps.iterrows():
    checkout_master_fetch_and_reset(f'../../repos/{app["APPLICATION_NAME"]}')
# Out:
# 2025-04-12 23:45:54,662 - INFO - Checkout master of ../../repos/prepaid-api
# 2025-04-12 23:45:54,675 - INFO - Reset ../../repos/prepaid-api
# 2025-04-12 23:45:54,696 - INFO - Checkout master of ../../repos/prepaid-product-api
# 2025-04-12 23:45:54,732 - INFO - Reset ../../repos/prepaid-product-api
# 2025-04-12 23:45:54,751 - INFO - Checkout master of ../../repos/sp-device-api
# 2025-04-12 23:45:54,768 - INFO - Reset ../../repos/sp-device-api
# 2025-04-12 23:45:54,781 - INFO - Checkout master of ../../repos/sp-subscription-api
# 2025-04-12 23:45:54,806 - INFO - Reset ../../repos/sp-subscription-api
# 2025-04-12 23:45:54,821 - INFO - Checkout master of ../../repos/prepaid-middle-end
# 2025-04-12 23:45:54,851 - INFO - Reset ../../repos/prepaid-middle-end
# 2025-04-12 23:45:54,867 - INFO - Checkout master of ../../repos/sp-prepaid-wrapper
# 2025-04-12 23:45:54,891 - INFO - Reset ../../repos/sp-prepaid-wrapper
# 2025-04-12 23:45:54,905 - INFO - Checkout master of ../../repos/prepaid-esitef-api
# 2025-04-12 23:45:54,936 - INFO - Reset ../../repos/prepaid-esitef-api
# 2025-04-12 23:45:54,953 - INFO - Checkout master of ../../repos/prepaid-personal-api
# 2025-04-12 23:45:54,978 - INFO - Reset ../../repos/prepaid-personal-api
# 2025-04-12 23:45:54,992 - INFO - Checkout master of ../../repos/prepaid-semovi-api
# 2025-04-12 23:45:55,014 - INFO - Reset ../../repos/prepaid-semovi-api
# 2025-04-12 23:45:55,028 - INFO - Checkout master of ../../repos/prepaid-sube-api
# 2025-04-12 23:45:55,054 - INFO - Reset ../../repos/prepaid-sube-api
# 2025-04-12 23:45:55,069 - INFO - Checkout master of ../../repos/prepaid-telcel-api
# 2025-04-12 23:45:55,091 - INFO - Reset ../../repos/prepaid-telcel-api
# 2025-04-12 23:45:55,108 - INFO - Checkout master of ../../repos/sp-prepaid-directconnect-api
# 2025-04-12 23:45:55,132 - INFO - Reset ../../repos/sp-prepaid-directconnect-api
# 2025-04-12 23:45:55,146 - INFO - Checkout master of ../../repos/clearance-api
# 2025-04-12 23:45:55,167 - INFO - Reset ../../repos/clearance-api
# 2025-04-12 23:45:55,180 - INFO - Checkout master of ../../repos/top-up-middleware
# 2025-04-12 23:45:55,202 - INFO - Reset ../../repos/top-up-middleware
# 2025-04-12 23:45:55,216 - INFO - Checkout master of ../../repos/prepaid-accounts-api
# 2025-04-12 23:45:55,233 - INFO - Reset ../../repos/prepaid-accounts-api
# 2025-04-12 23:45:55,248 - INFO - Checkout master of ../../repos/sp-ticket-api
# 2025-04-12 23:45:55,268 - INFO - Reset ../../repos/sp-ticket-api
# 2025-04-12 23:45:55,283 - INFO - Checkout master of ../../repos/pay-as-you-go-api
# 2025-04-12 23:45:55,316 - INFO - Reset ../../repos/pay-as-you-go-api
# 2025-04-12 23:45:55,334 - INFO - Checkout master of ../../repos/paygo-taggy-api
# 2025-04-12 23:45:55,366 - INFO - Reset ../../repos/paygo-taggy-api
# 2025-04-12 23:45:55,383 - INFO - Checkout master of ../../repos/paygo-telepase-api
# 2025-04-12 23:45:55,424 - INFO - Reset ../../repos/paygo-telepase-api
# 2025-04-12 23:45:55,441 - INFO - Checkout master of ../../repos/sp-charge-engine-api
# 2025-04-12 23:45:55,462 - INFO - Reset ../../repos/sp-charge-engine-api
# 2025-04-12 23:45:55,477 - INFO - Checkout master of ../../repos/sp-paygo-api
# 2025-04-12 23:45:55,501 - INFO - Reset ../../repos/sp-paygo-api
# 2025-04-12 23:45:55,514 - INFO - Checkout master of ../../repos/sp-utilities-provider-api
# 2025-04-12 23:45:55,558 - INFO - Reset ../../repos/sp-utilities-provider-api
# 2025-04-12 23:45:55,576 - INFO - Checkout master of ../../repos/sp-payments-core
# 2025-04-12 23:45:55,614 - INFO - Reset ../../repos/sp-payments-core
# 2025-04-12 23:45:55,636 - INFO - Checkout master of ../../repos/sp-message-listener-api
# 2025-04-12 23:45:55,666 - INFO - Reset ../../repos/sp-message-listener-api
# 2025-04-12 23:45:55,683 - INFO - Checkout master of ../../repos/sp-activities-api
# 2025-04-12 23:45:55,709 - INFO - Reset ../../repos/sp-activities-api
# 2025-04-12 23:45:55,726 - INFO - Checkout master of ../../repos/self-service-api
# 2025-04-12 23:45:55,769 - INFO - Reset ../../repos/self-service-api
# 2025-04-12 23:45:55,787 - INFO - Checkout master of ../../repos/self-service-collection-api
# 2025-04-12 23:45:55,816 - INFO - Reset ../../repos/self-service-collection-api
# 2025-04-12 23:45:55,831 - INFO - Checkout master of ../../repos/self-service-file-api
# 2025-04-12 23:45:55,867 - INFO - Reset ../../repos/self-service-file-api
# 2025-04-12 23:45:55,883 - INFO - Checkout master of ../../repos/dt-benefits-backend
# 2025-04-12 23:45:55,907 - INFO - Reset ../../repos/dt-benefits-backend
# 2025-04-12 23:45:55,924 - INFO - Checkout master of ../../repos/prepaid-rola-api
# 2025-04-12 23:45:55,949 - INFO - Reset ../../repos/prepaid-rola-api

# %%
import pandas as pd
import re
from dateutil.relativedelta import relativedelta

release_version_pattern = re.compile(r'^\d+\.\d+\.\d+$')

# Suponiendo que df es tu DataFrame con las columnas: class, tag_name, tag_date, APPLICATION_NAME
df = pd.read_csv(f"../datasets/apps_ck_versions.csv")
first_release_dates = pd.read_csv(f"../datasets/applications_first_release_date.csv")

# Convertir tag_date a datetime si no lo está
df['tag_date'] = pd.to_datetime(df['tag_date'])

# Filtrar las versiones que coincidan con el patrón de versión release
release_versions = df[df['tag_name'].apply(lambda x: bool(release_version_pattern.match(x)))]

# Eliminar duplicados basados en APPLICATION_NAME y tag_name
release_versions_unique = release_versions.drop_duplicates(subset=['APPLICATION_NAME', 'tag_name'])

# Obtener la fecha del primer release para cada aplicación
#first_release_dates = df.groupby('APPLICATION_NAME')['tag_date'].min().reset_index()
#first_release_dates = first_release_dates.rename(columns={'tag_date': 'first_release_date'})

# Obtener la fecha del ultimo release para cada aplicación
last_release_dates = df.groupby('APPLICATION_NAME')['tag_date'].max().reset_index()
last_release_dates = last_release_dates.rename(columns={'tag_date': 'last_release_date'})

# Obtener la cantidad de clases de la versión más reciente para cada aplicación
latest_versions = df.sort_values('tag_date').drop_duplicates('APPLICATION_NAME', keep='last')
latest_versions_class_counts = df[df['tag_date'].isin(latest_versions['tag_date'])].groupby('APPLICATION_NAME')['class'].nunique().reset_index()
latest_versions_class_counts = latest_versions_class_counts.rename(columns={'class': 'class_count'})

# Contar el número de versiones release únicas para cada aplicación
release_version_counts = release_versions_unique.groupby('APPLICATION_NAME').size().reset_index(name='release_version_count')

# Combinar los resultados en un solo DataFrame
result = pd.merge(first_release_dates, last_release_dates, on='APPLICATION_NAME')
result = pd.merge(result, latest_versions_class_counts, on='APPLICATION_NAME')
result = pd.merge(result, release_version_counts, on='APPLICATION_NAME')
#result['first_release_date'] = result['first_release_date'].dt.strftime('%Y-%m-%d')
#result['last_release_date'] = result['last_release_date'].dt.strftime('%Y-%m-%d')

# Calcular la diferencia en meses entre el primer y el último release
def diff_months(d1, d2):
    rd = relativedelta(d2, d1)
    return rd.years * 12 + rd.months + 1  # +1 para incluir el mes de inicio

result['active_months'] = result.apply(
    lambda row: diff_months(row['first_release_date'], row['last_release_date']),
    axis=1
)

# Calcular la densidad de releases (releases por mes)
result['release_density'] = (result['release_version_count'] / result['active_months']).round(2)

# Clasificar la actividad del repositorio
def clasificar_actividad(density):
    if density >= 2:
        return '🟢 Alta'
    elif density >= 1:
        return '🟡 Media'
    else:
        return '🔴 Baja'

result['activity_level'] = result['release_density'].apply(clasificar_actividad)

# Ordenar los resultados alfabéticamente por APPLICATION_NAME
result = result.sort_values(by='activity_level', ascending=False)

# Mostrar el resultado
result
result.to_csv('../output/repos_stats_full.csv', index=False)  # Guardar el resultado en un archivo CSV

# %%
import pandas as pd

# Suponiendo que df es tu DataFrame con las columnas: class, tag_name, tag_date, APPLICATION_NAME
df = pd.read_csv(f"../datasets/apps_deploys.csv")

df = df[df['DEPLOY_STATUS'].isin(['finished', 'rollbacked'])]
df = df[df['DEPLOY_STRATEGY'].isin(['BlueGreenDeployment', 'InitialDeployment', 'SafeDeployment'])]
df = df[df['APPLICATION_NAME'] == 'dt-benefits-backend']

# FILTER DEPLOY_DATE during april 2024
df['DEPLOY_DATE'] = pd.to_datetime(df['DEPLOY_DATE'], format='mixed')
df = df[(df['DEPLOY_DATE'] >= '2024-10-01') & (df['DEPLOY_DATE'] < '2024-11-01')]

# sort by SERVICE_NAME and DEPLOY_DATE
df = df.sort_values(by=['SERVICE_NAME', 'DEPLOY_DATE'])

df
# Out:
# ['bu-critical' 'medium' 'low' 'high']
#       DEPLOY_ID     APPLICATION_NAME               SERVICE_NAME  \
# 4931   19740940  dt-benefits-backend  create-benefit-scope-prod
# 4980   19869832  dt-benefits-backend  create-benefit-scope-prod
# 5054   19900614  dt-benefits-backend  create-benefit-scope-prod
# 5052   19904437  dt-benefits-backend  create-benefit-scope-prod
# 5414   19932701  dt-benefits-backend  create-benefit-scope-prod
# 7003   20140990  dt-benefits-backend  create-benefit-scope-prod
# 6058   19546888  dt-benefits-backend             job-scope-prod
# 4932   19740941  dt-benefits-backend             job-scope-prod
# 4979   19869830  dt-benefits-backend             job-scope-prod
# 5056   19900613  dt-benefits-backend             job-scope-prod
# 5055   19904439  dt-benefits-backend             job-scope-prod
# 5413   19932700  dt-benefits-backend             job-scope-prod
# 7002   20140992  dt-benefits-backend             job-scope-prod
# 6057   19546887  dt-benefits-backend                       prod
# 4929   19740942  dt-benefits-backend                       prod
# 4933   19772161  dt-benefits-backend                       prod
# 4934   19774465  dt-benefits-backend                       prod
# 4978   19869828  dt-benefits-backend                       prod
# 5051   19900615  dt-benefits-backend                       prod
# 5053   19904438  dt-benefits-backend                       prod
# 5412   19932702  dt-benefits-backend                       prod
# 7004   20140989  dt-benefits-backend                       prod
# 5916   19540196  dt-benefits-backend                    staging
# 4930   19740939  dt-benefits-backend                    staging
# 4977   19869829  dt-benefits-backend                    staging
# 7005   20140991  dt-benefits-backend                    staging
#
#                               SERVICE_TYPE SERVICE_CRITICALLITY  \
# 4931  BigqueueServerlessApplicationService                  low
# 4980  BigqueueServerlessApplicationService                  low
# 5054  BigqueueServerlessApplicationService                  low
# 5052  BigqueueServerlessApplicationService                  low
# 5414  BigqueueServerlessApplicationService                  low
# 7003  BigqueueServerlessApplicationService                  low
# 6058       JobServerlessApplicationService                  low
# 4932       JobServerlessApplicationService                  low
# 4979       JobServerlessApplicationService                  low
# 5056       JobServerlessApplicationService                  low
# 5055       JobServerlessApplicationService                  low
# 5413       JobServerlessApplicationService                  low
# 7002       JobServerlessApplicationService                  low
# 6057       WebServerlessApplicationService               medium
# 4929       WebServerlessApplicationService               medium
# 4933       WebServerlessApplicationService               medium
# 4934       WebServerlessApplicationService               medium
# 4978       WebServerlessApplicationService               medium
# 5051       WebServerlessApplicationService               medium
# 5053       WebServerlessApplicationService               medium
# 5412       WebServerlessApplicationService               medium
# 7004       WebServerlessApplicationService               medium
# 5916       WebServerlessApplicationService                  low
# 4930       WebServerlessApplicationService                  low
# 4977       WebServerlessApplicationService                  low
# 7005       WebServerlessApplicationService                  low
#
#              DEPLOY_DATE DEPLOY_NEW_VERSION DEPLOY_PREVIOUS_VERSION  \
# 4931 2024-10-10 02:55:42        0.21.0-rc-1             0.20.0-rc-1
# 4980 2024-10-17 03:04:10        0.21.0-rc-2             0.21.0-rc-1
# 5054 2024-10-18 12:42:51    0.20.2-hotfix-1             0.21.0-rc-2
# 5052 2024-10-18 15:10:17    0.20.2-hotfix-2         0.20.2-hotfix-1
# 5414 2024-10-21 16:36:21    0.21.1-hotfix-2         0.20.2-hotfix-2
# 7003 2024-10-31 03:19:38        0.22.0-rc-1         0.21.1-hotfix-2
# 6058 2024-10-03 03:05:50        0.20.0-rc-1             0.19.0-rc-1
# 4932 2024-10-10 02:55:42        0.21.0-rc-1             0.20.0-rc-1
# 4979 2024-10-17 03:04:09        0.21.0-rc-2             0.21.0-rc-1
# 5056 2024-10-18 12:42:51    0.20.2-hotfix-1             0.21.0-rc-2
# 5055 2024-10-18 15:10:17    0.20.2-hotfix-2         0.20.2-hotfix-1
# 5413 2024-10-21 16:36:20    0.21.1-hotfix-2         0.20.2-hotfix-2
# 7002 2024-10-31 03:19:38        0.22.0-rc-1         0.21.1-hotfix-2
# 6057 2024-10-03 03:05:50        0.20.0-rc-1             0.19.0-rc-1
# 4929 2024-10-10 02:55:42        0.21.0-rc-1             0.20.0-rc-1
# 4933 2024-10-10 19:06:34    0.20.1-hotfix-2             0.21.0-rc-1
# 4934 2024-10-10 19:56:36    0.20.1-hotfix-4         0.20.1-hotfix-2
# 4978 2024-10-17 03:04:09        0.21.0-rc-2         0.20.1-hotfix-4
# 5051 2024-10-18 12:42:51    0.20.2-hotfix-1             0.21.0-rc-2
# 5053 2024-10-18 15:10:17    0.20.2-hotfix-2         0.20.2-hotfix-1
# 5412 2024-10-21 16:36:21    0.21.1-hotfix-2         0.20.2-hotfix-2
# 7004 2024-10-31 03:19:38        0.22.0-rc-1         0.21.1-hotfix-2
# 5916 2024-10-02 20:14:21        0.20.0-rc-1             0.16.0-rc-2
# 4930 2024-10-10 02:55:42        0.21.0-rc-1             0.16.0-rc-2
# 4977 2024-10-17 03:04:09        0.21.0-rc-2             0.16.0-rc-2
# 7005 2024-10-31 03:19:38        0.22.0-rc-1             0.16.0-rc-2
#
#           DEPLOY_STRATEGY DEPLOY_STATUS
# 4931  BlueGreenDeployment      finished
# 4980  BlueGreenDeployment      finished
# 5054  BlueGreenDeployment      finished
# 5052  BlueGreenDeployment      finished
# 5414  BlueGreenDeployment      finished
# 7003  BlueGreenDeployment      finished
# 6058  BlueGreenDeployment      finished
# 4932  BlueGreenDeployment      finished
# 4979  BlueGreenDeployment      finished
# 5056  BlueGreenDeployment      finished
# 5055  BlueGreenDeployment      finished
# 5413  BlueGreenDeployment      finished
# 7002  BlueGreenDeployment      finished
# 6057  BlueGreenDeployment      finished
# 4929  BlueGreenDeployment      finished
# 4933  BlueGreenDeployment      finished
# 4934  BlueGreenDeployment      finished
# 4978  BlueGreenDeployment      finished
# 5051  BlueGreenDeployment      finished
# 5053  BlueGreenDeployment      finished
# 5412  BlueGreenDeployment      finished
# 7004  BlueGreenDeployment      finished
# 5916  BlueGreenDeployment    rollbacked
# 4930  BlueGreenDeployment    rollbacked
# 4977  BlueGreenDeployment    rollbacked
# 7005  BlueGreenDeployment    rollbacked
